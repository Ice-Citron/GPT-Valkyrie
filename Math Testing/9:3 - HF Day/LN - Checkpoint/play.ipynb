# %%
#%%capture

# new variant. for Python3.10+ in Ubuntu
"""
sudo apt-get update
sudo apt-get install software-properties-common

sudo add-apt-repository ppa:deadsnakes/ppa
sudo apt-get update
sudo apt-get install python3.10

sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.8 1
sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.10 2
sudo update-alternatives --config python3
python3 --version
"""
# before using pip, seems like i need to reinstall a lot of things :(
"""
sudo apt-get install python3.10-distutils -y
sudo apt-get install build-essential libssl-dev libncurses5-dev libsqlite3-dev libreadline-dev libbz2-dev libffi-dev zlib1g-dev liblzma-dev

curl https://bootstrap.pypa.io/get-pip.py -o get-pip.py
python3.10 get-pip.py
"""
"""
python3 -m pip install --upgrade pip
python3 -m pip install jupyter
"""

"""
sudo apt-get update
sudo apt-get install python3-dev
# sudo apt-get install libpython-dev  //. seems to be useless?
sudo apt-get install libpython3.10-dev
"""

# %%
# train_gpt2.py DDP run for 4 GPUs
torchrun --standalone --nproc_per_node=4 train_gpt2.py

# LLMC variant
torchrun --standalone --nproc_per_node=4 LLMC_train_gpt2.py --write_tensors=0 --compile=1 --tensorcores=1 --dtype=bfloat16

# %%
# Verify the installation
# !python --version
# !python3 --version

# for retrieving sysconfig for python3.10
# !python3.10 -m sysconfig
            # INCLUDEDIR = "/usr/include"
            # INCLUDEPY = "/usr/include/python3.10"
# Out:
# Python 3.11.9
# Python 3.11.9

# %%
import sysconfig
print(sysconfig.get_paths()['include'])
# Out:
# /home/user/mambaforge/envs/env/include/python3.11

# %%
#%%capture
#"""
# !pip install transformers==4.41.2
# !pip install datasets==2.20.0

# !pip install pyarrow==16.0
# !pip install requests==2.32.3

# !pip install torch==2.3.0 torchvision==0.18.0 torchaudio==2.3.0
# !pip install importlib-metadata
# !pip install accelerate -U
# !pip install psutil==6.0.0

# !pip install tiktoken


# Specific to Nvidia Instance
# !pip install matplotlib==3.9.1
# !pip install --upgrade cython
# !pip install testresources # newly added
# !pip install --upgrade --force-reinstall ipython
# !pip install pickleshare
# !sudo apt-get install git-lfs

# Specific to Nvidia Instance + Training GPT
# !pip install tensorboard==2.17.0
# !pip install wandb==0.17.5
#"""
# Out:
# Collecting transformers==4.41.2
#   Downloading transformers-4.41.2-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 15.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from transformers==4.41.2) (3.15.4)
# Collecting huggingface-hub<1.0,>=0.23.0 (from transformers==4.41.2)
#   Downloading huggingface_hub-0.24.6-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from transformers==4.41.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from transformers==4.41.2) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from transformers==4.41.2) (6.0.1)
# Collecting regex!=2019.12.17 (from transformers==4.41.2)
#   Downloading regex-2024.7.24-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: requests in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from transformers==4.41.2) (2.32.3)
# Collecting tokenizers<0.20,>=0.19 (from transformers==4.41.2)
#   Downloading tokenizers-0.19.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.1 (from transformers==4.41.2)
#   Downloading safetensors-0.4.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting tqdm>=4.27 (from transformers==4.41.2)
#   Downloading tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 15.3 MB/s eta 0:00:00
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.2)
#   Downloading fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.2) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from requests->transformers==4.41.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from requests->transformers==4.41.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from requests->transformers==4.41.2) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from requests->transformers==4.41.2) (2024.6.2)
# Downloading transformers-4.41.2-py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 156.1 MB/s eta 0:00:00a 0:00:01
# Downloading huggingface_hub-0.24.6-py3-none-any.whl (417 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.5/417.5 kB 99.3 MB/s eta 0:00:00
# Downloading regex-2024.7.24-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (786 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 786.6/786.6 kB 120.8 MB/s eta 0:00:00
# Downloading safetensors-0.4.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.4/435.4 kB 101.5 MB/s eta 0:00:00
# Downloading tokenizers-0.19.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 185.5 MB/s eta 0:00:00
# Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 27.8 MB/s eta 0:00:00
# Downloading fsspec-2024.6.1-py3-none-any.whl (177 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 58.0 MB/s eta 0:00:00
# Installing collected packages: tqdm, safetensors, regex, fsspec, huggingface-hub, tokenizers, transformers
# Successfully installed fsspec-2024.6.1 huggingface-hub-0.24.6 regex-2024.7.24 safetensors-0.4.4 tokenizers-0.19.1 tqdm-4.66.5 transformers-4.41.2
# Collecting datasets==2.20.0
#   Downloading datasets-2.20.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from datasets==2.20.0) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from datasets==2.20.0) (1.26.4)
# Collecting pyarrow>=15.0.0 (from datasets==2.20.0)
#   Downloading pyarrow-17.0.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting pyarrow-hotfix (from datasets==2.20.0)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets==2.20.0)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from datasets==2.20.0) (2.1.1)
# Requirement already satisfied: requests>=2.32.2 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from datasets==2.20.0) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from datasets==2.20.0) (4.66.5)
# Collecting xxhash (from datasets==2.20.0)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets==2.20.0)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.5.0,>=2023.1.0 (from fsspec[http]<=2024.5.0,>=2023.1.0->datasets==2.20.0)
#   Downloading fsspec-2024.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting aiohttp (from datasets==2.20.0)
#   Downloading aiohttp-3.10.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from datasets==2.20.0) (0.24.6)
# Requirement already satisfied: packaging in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from datasets==2.20.0) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from datasets==2.20.0) (6.0.1)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp->datasets==2.20.0)
#   Downloading aiohappyeyeballs-2.4.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets==2.20.0)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from aiohttp->datasets==2.20.0) (23.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets==2.20.0)
#   Downloading frozenlist-1.4.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets==2.20.0)
#   Downloading multidict-6.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets==2.20.0)
#   Downloading yarl-1.9.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (39 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from huggingface-hub>=0.21.2->datasets==2.20.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from requests>=2.32.2->datasets==2.20.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from requests>=2.32.2->datasets==2.20.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from requests>=2.32.2->datasets==2.20.0) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from requests>=2.32.2->datasets==2.20.0) (2024.6.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from pandas->datasets==2.20.0) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from pandas->datasets==2.20.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from pandas->datasets==2.20.0) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets==2.20.0) (1.16.0)
# Downloading datasets-2.20.0-py3-none-any.whl (547 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 70.1 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 26.5 MB/s eta 0:00:00
# Downloading fsspec-2024.5.0-py3-none-any.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.1/316.1 kB 90.9 MB/s eta 0:00:00
# Downloading aiohttp-3.10.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 154.1 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp311-cp311-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 102.6 MB/s eta 0:00:0000:0100:01
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 38.3 MB/s eta 0:00:00
# Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 50.6 MB/s eta 0:00:00
# Downloading aiohappyeyeballs-2.4.0-py3-none-any.whl (12 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading frozenlist-1.4.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (272 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.3/272.3 kB 64.6 MB/s eta 0:00:00
# Downloading multidict-6.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.7/128.7 kB 45.1 MB/s eta 0:00:00
# Downloading yarl-1.9.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (508 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.0/508.0 kB 100.1 MB/s eta 0:00:00
# Installing collected packages: xxhash, pyarrow-hotfix, pyarrow, multidict, fsspec, frozenlist, dill, aiohappyeyeballs, yarl, multiprocess, aiosignal, aiohttp, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.6.1
#     Uninstalling fsspec-2024.6.1:
#       Successfully uninstalled fsspec-2024.6.1
# Successfully installed aiohappyeyeballs-2.4.0 aiohttp-3.10.5 aiosignal-1.3.1 datasets-2.20.0 dill-0.3.8 frozenlist-1.4.1 fsspec-2024.5.0 multidict-6.0.5 multiprocess-0.70.16 pyarrow-17.0.0 pyarrow-hotfix-0.6 xxhash-3.5.0 yarl-1.9.7
# Collecting pyarrow==16.0
#   Downloading pyarrow-16.0.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy>=1.16.6 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from pyarrow==16.0) (1.26.4)
# Downloading pyarrow-16.0.0-cp311-cp311-manylinux_2_28_x86_64.whl (40.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 82.2 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: pyarrow
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 17.0.0
#     Uninstalling pyarrow-17.0.0:
#       Successfully uninstalled pyarrow-17.0.0
# Successfully installed pyarrow-16.0.0
# Requirement already satisfied: requests==2.32.3 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from requests==2.32.3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from requests==2.32.3) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from requests==2.32.3) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from requests==2.32.3) (2024.6.2)
# Collecting torch==2.3.0
#   Downloading torch-2.3.0-cp311-cp311-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting torchvision==0.18.0
#   Downloading torchvision-0.18.0-cp311-cp311-manylinux1_x86_64.whl.metadata (6.6 kB)
# Collecting torchaudio==2.3.0
#   Downloading torchaudio-2.3.0-cp311-cp311-manylinux1_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: filelock in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from torch==2.3.0) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from torch==2.3.0) (4.12.2)
# Requirement already satisfied: sympy in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from torch==2.3.0) (1.12.1)
# Requirement already satisfied: networkx in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from torch==2.3.0) (3.3)
# Requirement already satisfied: jinja2 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from torch==2.3.0) (3.1.4)
# Requirement already satisfied: fsspec in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from torch==2.3.0) (2024.5.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.3.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.3.0)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.3.0)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.3.0)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.3.0)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.3.0)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.3.0)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.3.0)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.3.0)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch==2.3.0)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.3.0)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.3.0 (from torch==2.3.0)
#   Downloading triton-2.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: numpy in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from torchvision==0.18.0) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from torchvision==0.18.0) (10.4.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.0)
#   Downloading nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from jinja2->torch==2.3.0) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from sympy->torch==2.3.0) (1.3.0)
# Downloading torch-2.3.0-cp311-cp311-manylinux1_x86_64.whl (779.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.2/779.2 MB 7.5 MB/s eta 0:00:00:00:0100:01
# Downloading torchvision-0.18.0-cp311-cp311-manylinux1_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 132.9 MB/s eta 0:00:00a 0:00:01
# Downloading torchaudio-2.3.0-cp311-cp311-manylinux1_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 135.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 13.0 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 125.7 MB/s eta 0:00:0000:010:01
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 115.6 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 115.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 7.4 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 38.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 71.7 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 40.0 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 26.6 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 28.5 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 25.3 MB/s eta 0:00:00
# Downloading triton-2.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (168.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.1/168.1 MB 29.8 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 63.5 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision, torchaudio
#   Attempting uninstall: triton
#     Found existing installation: triton 2.3.1
#     Uninstalling triton-2.3.1:
#       Successfully uninstalled triton-2.3.1
#   Attempting uninstall: torch
#     Found existing installation: torch 2.3.1
#     Uninstalling torch-2.3.1:
#       Successfully uninstalled torch-2.3.1
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.18.1
#     Uninstalling torchvision-0.18.1:
#       Successfully uninstalled torchvision-0.18.1
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.3.1
#     Uninstalling torchaudio-2.3.1:
#       Successfully uninstalled torchaudio-2.3.1
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.68 nvidia-nvtx-cu12-12.1.105 torch-2.3.0 torchaudio-2.3.0 torchvision-0.18.0 triton-2.3.0
# Requirement already satisfied: importlib-metadata in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (8.0.0)
# Requirement already satisfied: zipp>=0.5 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from importlib-metadata) (3.19.2)
# Requirement already satisfied: psutil==6.0.0 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (6.0.0)
# Collecting tiktoken
#   Downloading tiktoken-0.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: regex>=2022.1.18 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from tiktoken) (2024.7.24)
# Requirement already satisfied: requests>=2.26.0 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken) (2024.6.2)
# Downloading tiktoken-0.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 70.7 MB/s eta 0:00:00
# Installing collected packages: tiktoken
# Successfully installed tiktoken-0.7.0
# Collecting matplotlib==3.9.1
#   Downloading matplotlib-3.9.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from matplotlib==3.9.1) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from matplotlib==3.9.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from matplotlib==3.9.1) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from matplotlib==3.9.1) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from matplotlib==3.9.1) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from matplotlib==3.9.1) (24.1)
# Requirement already satisfied: pillow>=8 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from matplotlib==3.9.1) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from matplotlib==3.9.1) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from matplotlib==3.9.1) (2.9.0)
# Requirement already satisfied: six>=1.5 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib==3.9.1) (1.16.0)
# WARNING: The candidate selected for download or install is a yanked version: 'matplotlib' candidate (version 3.9.1 at https://files.pythonhosted.org/packages/b8/63/cef838d92c1918ae28afd12b8aeaa9c104a0686cf6447aa0546f7c6dd1f0/matplotlib-3.9.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from https://pypi.org/simple/matplotlib/) (requires-python:>=3.9))
# Reason for being yanked: The Windows wheels, under some conditions, caused segfaults in unrelated user code.  Due to this we deleted the Windows wheels to prevent these segfaults, however this caused greater disruption as pip then began to try (and fail) to build 3.9.1 from the sdist on Windows which impacted far more users.  Yanking the whole release is the only tool available to eliminate these failures without changes to on the user side.  The sdist, OSX wheel, and manylinux wheels are all functional and there are no critical bugs in the release.   Downstream packagers should not yank their builds of Matplotlib 3.9.1.  See https://github.com/matplotlib/matplotlib/issues/28551 for details.
# Downloading matplotlib-3.9.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 140.8 MB/s eta 0:00:0000:01
# Installing collected packages: matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.8.4
#     Uninstalling matplotlib-3.8.4:
#       Successfully uninstalled matplotlib-3.8.4
# Successfully installed matplotlib-3.9.1
# Collecting cython
#   Downloading Cython-3.0.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Downloading Cython-3.0.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 119.5 MB/s eta 0:00:00
# Installing collected packages: cython
# Successfully installed cython-3.0.11
# Collecting testresources
#   Downloading testresources-2.0.1-py2.py3-none-any.whl.metadata (11 kB)
# Collecting pbr>=1.8 (from testresources)
#   Downloading pbr-6.1.0-py2.py3-none-any.whl.metadata (3.4 kB)
# Downloading testresources-2.0.1-py2.py3-none-any.whl (36 kB)
# Downloading pbr-6.1.0-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.5/108.5 kB 29.3 MB/s eta 0:00:00
# Installing collected packages: pbr, testresources
# Successfully installed pbr-6.1.0 testresources-2.0.1
# Collecting ipython
#   Downloading ipython-8.27.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting decorator (from ipython)
#   Downloading decorator-5.1.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting jedi>=0.16 (from ipython)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting matplotlib-inline (from ipython)
#   Downloading matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# Collecting prompt-toolkit<3.1.0,>=3.0.41 (from ipython)
#   Downloading prompt_toolkit-3.0.47-py3-none-any.whl.metadata (6.4 kB)
# Collecting pygments>=2.4.0 (from ipython)
#   Downloading pygments-2.18.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting stack-data (from ipython)
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting traitlets>=5.13.0 (from ipython)
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting typing-extensions>=4.6 (from ipython)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting pexpect>4.3 (from ipython)
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting parso<0.9.0,>=0.8.3 (from jedi>=0.16->ipython)
#   Downloading parso-0.8.4-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting ptyprocess>=0.5 (from pexpect>4.3->ipython)
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting wcwidth (from prompt-toolkit<3.1.0,>=3.0.41->ipython)
#   Downloading wcwidth-0.2.13-py2.py3-none-any.whl.metadata (14 kB)
# Collecting executing>=1.2.0 (from stack-data->ipython)
#   Downloading executing-2.1.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack-data->ipython)
#   Downloading asttokens-2.4.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting pure-eval (from stack-data->ipython)
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting six>=1.12.0 (from asttokens>=2.1.0->stack-data->ipython)
#   Downloading six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Downloading ipython-8.27.0-py3-none-any.whl (818 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.0/819.0 kB 60.7 MB/s eta 0:00:00
# Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 144.1 MB/s eta 0:00:00
# Downloading pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 23.4 MB/s eta 0:00:00
# Downloading prompt_toolkit-3.0.47-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.4/386.4 kB 83.1 MB/s eta 0:00:00
# Downloading pygments-2.18.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 129.6 MB/s eta 0:00:00
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 26.3 MB/s eta 0:00:00
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Downloading matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading asttokens-2.4.1-py2.py3-none-any.whl (27 kB)
# Downloading executing-2.1.0-py2.py3-none-any.whl (25 kB)
# Downloading parso-0.8.4-py2.py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.7/103.7 kB 26.0 MB/s eta 0:00:00
# Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Downloading wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: wcwidth, pure-eval, ptyprocess, typing-extensions, traitlets, six, pygments, prompt-toolkit, pexpect, parso, executing, decorator, matplotlib-inline, jedi, asttokens, stack-data, ipython
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.13
#     Uninstalling wcwidth-0.2.13:
#       Successfully uninstalled wcwidth-0.2.13
#   Attempting uninstall: pure-eval
#     Found existing installation: pure-eval 0.2.2
#     Uninstalling pure-eval-0.2.2:
#       Successfully uninstalled pure-eval-0.2.2
#   Attempting uninstall: ptyprocess
#     Found existing installation: ptyprocess 0.7.0
#     Uninstalling ptyprocess-0.7.0:
#       Successfully uninstalled ptyprocess-0.7.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.14.3
#     Uninstalling traitlets-5.14.3:
#       Successfully uninstalled traitlets-5.14.3
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.18.0
#     Uninstalling Pygments-2.18.0:
#       Successfully uninstalled Pygments-2.18.0
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt_toolkit 3.0.47
#     Uninstalling prompt_toolkit-3.0.47:
#       Successfully uninstalled prompt_toolkit-3.0.47
#   Attempting uninstall: pexpect
#     Found existing installation: pexpect 4.9.0
#     Uninstalling pexpect-4.9.0:
#       Successfully uninstalled pexpect-4.9.0
#   Attempting uninstall: parso
#     Found existing installation: parso 0.8.4
#     Uninstalling parso-0.8.4:
#       Successfully uninstalled parso-0.8.4
#   Attempting uninstall: executing
#     Found existing installation: executing 2.0.1
#     Uninstalling executing-2.0.1:
#       Successfully uninstalled executing-2.0.1
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.1.1
#     Uninstalling decorator-5.1.1:
#       Successfully uninstalled decorator-5.1.1
#   Attempting uninstall: matplotlib-inline
#     Found existing installation: matplotlib-inline 0.1.7
#     Uninstalling matplotlib-inline-0.1.7:
#       Successfully uninstalled matplotlib-inline-0.1.7
#   Attempting uninstall: jedi
#     Found existing installation: jedi 0.19.1
#     Uninstalling jedi-0.19.1:
#       Successfully uninstalled jedi-0.19.1
#   Attempting uninstall: asttokens
#     Found existing installation: asttokens 2.4.1
#     Uninstalling asttokens-2.4.1:
#       Successfully uninstalled asttokens-2.4.1
#   Attempting uninstall: stack-data
#     Found existing installation: stack-data 0.6.2
#     Uninstalling stack-data-0.6.2:
#       Successfully uninstalled stack-data-0.6.2
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.26.0
#     Uninstalling ipython-8.26.0:
#       Successfully uninstalled ipython-8.26.0
# Successfully installed asttokens-2.4.1 decorator-5.1.1 executing-2.1.0 ipython-8.27.0 jedi-0.19.1 matplotlib-inline-0.1.7 parso-0.8.4 pexpect-4.9.0 prompt-toolkit-3.0.47 ptyprocess-0.7.0 pure-eval-0.2.3 pygments-2.18.0 six-1.16.0 stack-data-0.6.3 traitlets-5.14.3 typing-extensions-4.12.2 wcwidth-0.2.13
# Requirement already satisfied: pickleshare in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (0.7.5)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   git-lfs
# 0 upgraded, 1 newly installed, 0 to remove and 29 not upgraded.
# Need to get 3503 kB of archives.
# After this operation, 10.4 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 git-lfs amd64 3.0.2-1ubuntu0.2 [3503 kB]
# Fetched 3503 kB in 1s (2872 kB/s)
# Selecting previously unselected package git-lfs.
# (Reading database ... 103838 files and directories currently installed.)
# Preparing to unpack .../git-lfs_3.0.2-1ubuntu0.2_amd64.deb ...
# Unpacking git-lfs (3.0.2-1ubuntu0.2) ...
# Setting up git-lfs (3.0.2-1ubuntu0.2) ...
# Processing triggers for man-db (2.10.2-1) ...
# Scanning processes...
# Scanning linux images...
#
# Running kernel seems to be up-to-date.
#
# No services need to be restarted.
#
# No containers need to be restarted.
#
# No user sessions are running outdated binaries.
#
# No VM guests are running outdated hypervisor (qemu) binaries on this host.
# Collecting tensorboard==2.17.0
#   Downloading tensorboard-2.17.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting absl-py>=0.4 (from tensorboard==2.17.0)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard==2.17.0)
#   Downloading grpcio-1.66.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting markdown>=2.6.8 (from tensorboard==2.17.0)
#   Downloading Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: numpy>=1.12.0 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from tensorboard==2.17.0) (1.26.4)
# Collecting protobuf!=4.24.0,<5.0.0,>=3.19.6 (from tensorboard==2.17.0)
#   Downloading protobuf-4.25.4-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools>=41.0.0 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from tensorboard==2.17.0) (70.1.1)
# Requirement already satisfied: six>1.9 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from tensorboard==2.17.0) (1.16.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard==2.17.0)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard==2.17.0)
#   Downloading werkzeug-3.0.4-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard==2.17.0) (2.1.5)
# Downloading tensorboard-2.17.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 155.0 MB/s eta 0:00:0000:01
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 42.3 MB/s eta 0:00:00
# Downloading grpcio-1.66.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 207.9 MB/s eta 0:00:00
# Downloading Markdown-3.7-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.3/106.3 kB 34.2 MB/s eta 0:00:00
# Downloading protobuf-4.25.4-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 79.8 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 212.0 MB/s eta 0:00:00
# Downloading werkzeug-3.0.4-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 65.9 MB/s eta 0:00:00
# Installing collected packages: werkzeug, tensorboard-data-server, protobuf, markdown, grpcio, absl-py, tensorboard
# Successfully installed absl-py-2.1.0 grpcio-1.66.1 markdown-3.7 protobuf-4.25.4 tensorboard-2.17.0 tensorboard-data-server-0.7.2 werkzeug-3.0.4
# Collecting wandb==0.17.5
#   Downloading wandb-0.17.5-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting click!=8.0.0,>=7.1 (from wandb==0.17.5)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting docker-pycreds>=0.4.0 (from wandb==0.17.5)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb==0.17.5)
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from wandb==0.17.5) (4.2.2)
# Requirement already satisfied: protobuf!=4.21.0,<6,>=3.19.0 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from wandb==0.17.5) (4.25.4)
# Requirement already satisfied: psutil>=5.0.0 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from wandb==0.17.5) (6.0.0)
# Requirement already satisfied: pyyaml in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from wandb==0.17.5) (6.0.1)
# Requirement already satisfied: requests<3,>=2.0.0 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from wandb==0.17.5) (2.32.3)
# Collecting sentry-sdk>=1.0.0 (from wandb==0.17.5)
#   Downloading sentry_sdk-2.13.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting setproctitle (from wandb==0.17.5)
#   Downloading setproctitle-1.3.3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.9 kB)
# Requirement already satisfied: setuptools in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from wandb==0.17.5) (70.1.1)
# Requirement already satisfied: six>=1.4.0 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from docker-pycreds>=0.4.0->wandb==0.17.5) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb==0.17.5)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb==0.17.5) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb==0.17.5) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb==0.17.5) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/user/mambaforge/envs/env/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb==0.17.5) (2024.6.2)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb==0.17.5)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Downloading wandb-0.17.5-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 163.3 MB/s eta 0:00:0000:01
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 32.3 MB/s eta 0:00:00
# Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 35.1 MB/s eta 0:00:00
# Downloading sentry_sdk-2.13.0-py2.py3-none-any.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 kB 64.8 MB/s eta 0:00:00
# Downloading setproctitle-1.3.3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 23.5 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, setproctitle, sentry-sdk, docker-pycreds, click, gitdb, gitpython, wandb
# Successfully installed click-8.1.7 docker-pycreds-0.4.0 gitdb-4.0.11 gitpython-3.1.43 sentry-sdk-2.13.0 setproctitle-1.3.3 smmap-5.0.1 wandb-0.17.5

# %%
#%%capture
# Verifying packages installed are now up to date
# !pip show pyarrow requests transformers datasets torch torchaudio importlib-metadata

# %%
# !nvidia-smi

# %%
# !cat /proc/cpuinfo

# %%
from transformers import GPT2LMHeadModel

# %%
model_hf = GPT2LMHeadModel.from_pretrained("gpt2") # 124M
sd_hf = model_hf.state_dict()

for k, v in sd_hf.items():
    print(k, v.shape)

# %%
sd_hf["transformer.wpe.weight"].view(-1)[:20]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.imshow(sd_hf["transformer.wpe.weight"], cmap="gray")

# %%
plt.plot(sd_hf["transformer.wpe.weight"][:, 150])
plt.plot(sd_hf["transformer.wpe.weight"][:, 200])
plt.plot(sd_hf["transformer.wpe.weight"][:, 250])

# %%
plt.imshow(sd_hf["transformer.h.1.attn.c_attn.weight"][:300,:300], cmap="gray")

# %%
from transformers import pipeline, set_seed
generator = pipeline('text-generation', model='gpt2')
set_seed(42)
generator("Hello, I'm a language model,", max_length=30, num_return_sequences=5)

# %%
# let's instead sample manually
import torch
from torch.nn import functional as F

model = GPT2LMHeadModel.from_pretrained("gpt2") # 124M
model.eval()
model.to('cuda')
torch.manual_seed(42)
torch.cuda.manual_seed(42)
tokens = [15496, 11, 314, 1101, 257, 3303, 2746, 11] # "Hello, I'm a language model,"
tokens = torch.tensor(tokens, dtype=torch.long) # (8,)
tokens = tokens.unsqueeze(0).repeat(5, 1) # (5, 8)
x = tokens.to('cuda')

# generate!
while x.size(1) < 30: # max_length=30
    # forward the model to get the logits
    with torch.no_grad():
        logits = model(x)[0] # (B, T, vocab_size)
        # take the logits at the last position
        logits = logits[:, -1, :] # (B, vocab_size)
        # get the probabilities
        probs = F.softmax(logits, dim=-1)
        # do top-k sampling of 50 (huggingface pipeline default)
        # topk_probs here becomes (5, 50), topk_indices is (5, 50)
        topk_probs, topk_indices = torch.topk(probs, 50, dim=-1)
        # select a token from the top-k probabilities
        # note: multinomial does not demand the input to sum to 1
        ix = torch.multinomial(topk_probs, 1) # (B, 1)
        # gather the corresponding indices
        xcol = torch.gather(topk_indices, -1, ix) # (B, 1)
        # append to the sequence
        x = torch.cat((x, xcol), dim=1)

# print the generated text
import tiktoken
enc = tiktoken.get_encoding('gpt2')
for i in range(5):
    tokens = x[i, :30].tolist()
    decoded = enc.decode(tokens)
    print(">", decoded)

# %%
# tiny shakespeare dataset
# !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('input.txt', 'r') as f:
    text = f.read()
data = text[:1000] # first 1,000 characters
print(data[:100])

# %%
import tiktoken
enc = tiktoken.get_encoding('gpt2')
tokens = enc.encode(data)
print(tokens[:24])

# %%
import torch
buf = torch.tensor(tokens[:24 + 1])
x = buf[:-1].view(4, 6)
y = buf[1:].view(4, 6)
print(x)
print(y)

# %%
print(sd_hf["lm_head.weight"].shape)
print(sd_hf["transformer.wte.weight"].shape)

# %%
(sd_hf["lm_head.weight"] == sd_hf["transformer.wte.weight"]).all()

# %%
print(sd_hf["lm_head.weight"].data_ptr())
print(sd_hf["transformer.wte.weight"].data_ptr())

# %%
# standard deviation grows inside the residual stream
x = torch.zeros(768)
n = 100 # e.g. 100 layers
for i in range(n):
    x += n**-0.5 * torch.randn(768)

print(x.std())

# %%
import torch

# super simple little MLP
net = torch.nn.Sequential(
    torch.nn.Linear(16, 32),
    torch.nn.GELU(),
    torch.nn.Linear(32, 1)
)
torch.random.manual_seed(42)
x = torch.randn(4, 16)
y = torch.randn(4, 1)
net.zero_grad()
yhat = net(x)
loss = torch.nn.functional.mse_loss(yhat, y)
loss.backward()
print(net[0].weight.grad.view(-1)[:10])

# the loss objective here is (due to readuction='mean')
# L = 1/4 * [
#            (y[0] - yhat[0])**2 +
#            (y[1] - yhat[1])**2 +
#            (y[2] - yhat[2])**2 +
#            (y[3] - yhat[3])**2
#           ]
# NOTE: 1/4!

# %%
# now let's do it with grad_accum_steps of 4, and B=1
# the loss objective here is different because
# accumulation in gradient <---> SUM in loss
# i.e. we instead get:
# L0 = 1/4(y[0] - yhat[0])**2
# L1 = 1/4(y[1] - yhat[1])**2
# L2 = 1/4(y[2] - yhat[2])**2
# L3 = 1/4(y[3] - yhat[3])**2
# L = L0 + L1 + L2 + L3
# NOTE: the "normalizer" of 1/4 is lost
net.zero_grad()
for i in range(4):
    yhat = net(x[i])
    loss = torch.nn.functional.mse_loss(yhat, y[i])
    loss = loss / 4 # <-- have to add back the "normalizer"!
    loss.backward()
print(net[0].weight.grad.view(-1)[:10])

# %%
# parse and visualize the logfile
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

sz = "124M"

loss_baseline = {
    "124M": 3.2924,
}[sz]
hella2_baseline = { # HellaSwag for GPT-2
    "124M": 0.294463,
    "350M": 0.375224,
    "774M": 0.431986,
    "1558M": 0.488946,
}[sz]
hella3_baseline = { # HellaSwag for GPT-3
    "124M": 0.337,
    "350M": 0.436,
    "774M": 0.510,
    "1558M": 0.547,
}[sz]

# load the log file
with open("log124M_40B/log.txt", "r") as f:
    lines = f.readlines()

# parse the individual lines, group by stream (train,val,hella)
streams = {}
for line in lines:
    step, stream, val = line.strip().split()
    if stream not in streams:
        streams[stream] = {}
    streams[stream][int(step)] = float(val)

# convert each stream from {step: val} to (steps[], vals[])
# so it's easier for plotting
streams_xy = {}
for k, v in streams.items():
    # get all (step, val) items, sort them
    xy = sorted(list(v.items()))
    # unpack the list of tuples to tuple of lists
    streams_xy[k] = list(zip(*xy))

# create figure
plt.figure(figsize=(16, 6))

# Panel 1: losses: both train and val
plt.subplot(121)
xs, ys = streams_xy["train"] # training loss
ys = np.array(ys)
plt.plot(xs, ys, label=f'nanogpt ({sz}) train loss')
print("Min Train Loss:", min(ys))
xs, ys = streams_xy["val"] # validation loss
plt.plot(xs, ys, label=f'nanogpt ({sz}) val loss')
# horizontal line at GPT-2 baseline
if loss_baseline is not None:
    plt.axhline(y=loss_baseline, color='r', linestyle='--', label=f"OpenAI GPT-2 ({sz}) checkpoint val loss")
plt.xlabel("steps")
plt.ylabel("loss")
plt.yscale('log')
plt.ylim(top=4.0)
plt.legend()
plt.title("Loss")
print("Min Validation Loss:", min(ys))

# Panel 2: HellaSwag eval
plt.subplot(122)
xs, ys = streams_xy["hella"] # HellaSwag eval
ys = np.array(ys)
plt.plot(xs, ys, label=f"nanogpt ({sz})")
# horizontal line at GPT-2 baseline
if hella2_baseline:
    plt.axhline(y=hella2_baseline, color='r', linestyle='--', label=f"OpenAI GPT-2 ({sz}) checkpoint")
if hella3_baseline:
    plt.axhline(y=hella3_baseline, color='g', linestyle='--', label=f"OpenAI GPT-3 ({sz}) checkpoint")
plt.xlabel("steps")
plt.ylabel("accuracy")
plt.legend()
plt.title("HellaSwag eval")
print("Max Hellaswag eval:", max(ys))
